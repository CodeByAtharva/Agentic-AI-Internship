# %% [markdown]
# ##✅Problem 1: Collect Student Details (Variables + Input + List)
#
# Write a Python program that:
#
# Takes the student name as input
#
# Takes marks for 3 subjects as input
#
# Stores the marks inside a list called marks
#
# Prints the name and marks list

# %%
name=input("Enter the your name: ")
print("Enter marks of 3 subject: ")
marks=[]
for i in range(3):
  marks.append(int(input(f"Subject {i+1}: ")))

print("\n\n---INFORMATION---")
print(f"Name: {name}")
print("Marks")
for i in range(3):
  print(f"Subject {i+1}: {marks[i]}")
# Out:
# Enter the your name: Atharva
# Enter marks of 3 subject:
# Subject 1: 90
# Subject 2: 75
# Subject 3: 30
#
#
# ---INFORMATION---
# Name: Atharva
# Marks
# Subject 1: 90
# Subject 2: 75
# Subject 3: 30

# %% [markdown]
# ##✅ Problem 2: Calculate Total and Average (Loop + List)
# Using the marks list from Problem 1:
#
# Use a loop to calculate the total marks
#
# Calculate the average marks
#
# Print both total and average

# %%
total=0
avg=0
for i in marks:
  total+=i
avg=total/3

print(f"Total marks: {total}")
print(f"Average marks: {avg}")
# Out:
# Total marks: 195
# Average marks: 65.0

# %% [markdown]
# ##✅ Problem 3: Decide Pass or Fail (Conditionals + Loop)
# Using the marks list:
#
# Check if the student has scored 35 or above in all subjects
#
# If yes → print "Pass"
#
# If no → print "Fail"

# %%
c=0
res="pass"
for i in marks:
  c+=1
  if i>=35:
    print(f"Pass in subject {c}")
  else:
      res="Fail"
      print(f"Fail in subject {c}")

print(f"\nResult: {res}")
# Out:
# Pass in subject 1
# Pass in subject 2
# Fail in subject 3
#
# Result: Fail

# %% [markdown]
# ##✅ Problem 4: Create a Student Dictionary (Dictionary + Key-Value Storage)
# Create a dictionary called student that stores:
#
# "name" → student name
#
# "marks" → list of marks
#
# "total" → total marks
#
# "average" → average marks
#
# "result" → pass/fail
#
# Print the full dictionary.

# %%
student={
    "name":name,
    "marks":marks,
    "total":total,
    "average":avg,
    "result":res
}
print(student)
# Out:
# {'name': 'Atharva', 'marks': [90, 75, 30], 'total': 195, 'average': 65.0, 'result': 'Fail'}

# %% [markdown]
# ##✅ Problem 5: Student Name Short Code (String Slicing)
# Write code that:
#
# Takes the student name
#
# Extracts and prints the first 3 letters using slicing

# %%
short_code=name[:3]
print(f"Short code for name {name} is '{short_code}'")
# Out:
# Short code for name Atharva is 'Ath'
