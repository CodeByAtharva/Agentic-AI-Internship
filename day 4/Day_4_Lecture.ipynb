# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GeminiApi'))

prompt=input("Enter your prompt: ")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt,
)

print(response.text)
# Out:
# Enter your promptwho is PM of India
# The current Prime Minister of India is **Narendra Modi**. He has been in office since May 26, 2014.

# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GeminiApi'))
history=[]
while True:
  prompt=input("Enter your prompt: ")
  history.append(f"User Input: {prompt}")
  if prompt == "stop":
    print("Good Bye..!")
    break
  else:
    response = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents=history,
    )
    history.append(f"LLM Output: {response.text}")
    print(response.text)

print(history)
# Out:
# Enter your prompt: hi i am Atharva
# Hi Atharva! It's nice to meet you. How can I help you today?
# Enter your prompt: 2+2
# 2 + 2 = 4
# Enter your prompt: who am i
# You are Atharva. You told me your name at the start of our conversation! How can I help you further?
# Enter your prompt: stop
# Good Bye..!
# ['User Input: hi i am Atharva', "LLM Output: Hi Atharva! It's nice to meet you. How can I help you today?", 'User Input: 2+2', 'LLM Output: 2 + 2 = 4', 'User Input: who am i', 'LLM Output: You are Atharva. You told me your name at the start of our conversation! How can I help you further?', 'User Input: stop']

# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GeminiApi'))
history=[]
while True:
  topic=input("Enter you topic")
  if topic == "stop":
    print("Good Bye..!")
    break
  else:
    prompt=f"First create a detailed content on the topic {topic}, and then give 5 point summary"
    history.append(f"User Input: {prompt}")
    response = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents=history,
    )
    history.append(f"LLM Output: {response.text}")
    print(response.text)

print(history)
# Out:
# Enter you topicQuantum Computing
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-785879401.py in <cell line: 0>()
#      12     prompt=f"First create a detailed content on the topic {topic}, and then give 5 point summary"
#      13     history.append(f"User Input: {prompt}")
# ---> 14     response = client.models.generate_content(
#      15         model="gemini-3-flash-preview",
#      16         contents=history,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5228     while remaining_remote_calls_afc > 0:
#    5229       i += 1
# -> 5230       response = self._generate_content(
#    5231           model=model, contents=contents, config=parsed_config
#    5232       )
#
# ...
