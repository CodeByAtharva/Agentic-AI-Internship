# %% [markdown]
# # 🧠 AI Health & Fitness Plan Generator (Using LangChain)
#
# ## 📌 Problem Statement
#
# The goal of this mini project is to build an **AI-powered Health and Fitness Plan Generator** using **LangChain** and a **Large Language Model (LLM)**.
#
# The system takes basic user health information such as age, weight, height, activity level, diet preference, and fitness goal, and generates a **personalized health plan**.
#
# Using a **multi-step LangChain workflow**, the application should:
# - Generate a **meal plan** with daily calorie intake and macro breakdown (protein, carbohydrates, fats)
# - Generate a **workout plan** including warm-up, main workout, and cool-down
# - Combine both outputs into a **weekly fitness strategy** with a schedule and motivational tips
#
# The final output should be displayed clearly inside the Google Colab notebook and exported as a **structured JSON file** (and optional Markdown file) for reuse and evaluation.
#
# This project demonstrates the use of **LangChain orchestration**, **structured output parsing with Pydantic**, and **end-to-end AI application development** in Python.

# %%
# !pip install langchain
# !pip install langchain-google-genai
# !pip install google-generativeai
# !pip install tavily-python

# %%
from google.colab import userdata
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser,PydanticOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
from tavily import TavilyClient
from pydantic import BaseModel, Field
from typing import Dict, List
from langchain_core.runnables import RunnableParallel
import json

# %%
GEMINI_API_KEY=userdata.get("GEMINI_API_KEY")
TAVILY_API_KEY=userdata.get("tavily")


llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",google_api_key=GEMINI_API_KEY)

# %%
class MealPlan(BaseModel):
    daily_calories: int = Field(description="Total calories per day")
    protein_g: int
    carbs_g: int
    fats_g: int
    breakfast: str
    lunch: str
    snacks: str
    dinner: str

class WorkoutPlan(BaseModel):
    frequency_per_week: int = Field(description="Number of workout days per week")
    warm_up: str
    main_workout: str
    cool_down: str

class WeeklyStrategy(BaseModel):
    weekly_schedule: Dict[str, str]
    motivation_tips: List[str]


meal_parser = PydanticOutputParser(pydantic_object=MealPlan)
workout_parser = PydanticOutputParser(pydantic_object=WorkoutPlan)
weekly_parser = PydanticOutputParser(pydantic_object=WeeklyStrategy)

# %%
meal_prompt = PromptTemplate(
    template="""
You are a certified nutritionist.

User Details:
Age: {age}
Weight (kg): {weight_kg}
Height (cm): {height_cm}
Activity Level: {activity_level}
Diet Preference: {diet_preference}
Fitness Goal: {fitness_goal}

Create a personalized meal plan.

Return output strictly in JSON.
{format_instructions}
""",
    input_variables=[
        "age", "weight_kg", "height_cm",
        "activity_level", "diet_preference", "fitness_goal"
    ],
    partial_variables={
        "format_instructions": meal_parser.get_format_instructions()
    }
)

workout_prompt = PromptTemplate(
    template="""
You are a professional fitness trainer.

User Details:
Age: {age}
Weight (kg): {weight_kg}
Height (cm): {height_cm}
Activity Level: {activity_level}
Fitness Goal: {fitness_goal}

Create a safe and effective workout plan.

Return output strictly in JSON.
{format_instructions}
""",
    input_variables=[
        "age", "weight_kg", "height_cm",
        "activity_level", "fitness_goal"
    ],
    partial_variables={
        "format_instructions": workout_parser.get_format_instructions()
    }
)

weekly_prompt = PromptTemplate(
    template="""
You are a health coach.

Meal Plan:
{meal_plan}

Workout Plan:
{workout_plan}

Combine both into a weekly strategy.
Include day-wise guidance and motivation tips.

Return output strictly in JSON.
{format_instructions}
""",
    input_variables=["meal_plan", "workout_plan"],
    partial_variables={
        "format_instructions": weekly_parser.get_format_instructions()
    }
)

# %%
meal_chain = meal_prompt | llm | meal_parser
workout_chain = workout_prompt | llm | workout_parser

parallel_chain = RunnableParallel(
    {
        "meal_plan": meal_chain,
        "workout_plan": workout_chain
    }
)


weekly_chain = weekly_prompt | llm | weekly_parser

# %%
user_input = {
    "age": 28,
    "weight_kg": 72,
    "height_cm": 175,
    "activity_level": "moderate",
    "diet_preference": "vegetarian",
    "fitness_goal": "fat loss"
}

parallel_output = parallel_chain.invoke(user_input)

final_output = weekly_chain.invoke({
    "meal_plan": parallel_output["meal_plan"].model_dump(),
    "workout_plan": parallel_output["workout_plan"].model_dump()
})

# %%
final_plan = {
    "meal_plan":parallel_output["meal_plan"].model_dump(),
    "workout_plan":parallel_output["workout_plan"].model_dump(),
    "weekly_strategy": final_output.model_dump()
}

with open("final_plan.json", "w") as f:
    json.dump(final_plan, f, indent=4)

print(json.dumps(final_plan, indent=2))
# Out:
# {
#   "meal_plan": {
#     "daily_calories": 2150,
#     "protein_g": 149,
#     "carbs_g": 279,
#     "fats_g": 52,
#     "breakfast": "High-Protein Greek Yogurt Bowl: 1 cup (200g) plain Greek yogurt, 1/2 cup mixed berries, 1 tbsp pumpkin seeds, 1/2 cup (cooked) rolled oats.",
#     "lunch": "Hearty Lentil & Chickpea Salad with Brown Rice: 1 cup (cooked) lentils, 1/2 cup (cooked) chickpeas, large portion of mixed greens and vegetables (cucumber, tomato, bell peppers), dressed with 1 tbsp olive oil and lemon juice. Served with 1 cup (cooked) brown rice.",
#     "snacks": "Mid-morning: 1 large apple. Mid-afternoon: Protein shake (1.5 scoops plant-based protein powder with water or unsweetened almond milk) and 1/4 cup almonds.",
#     "dinner": "Tofu & Vegetable Stir-fry with Brown Rice: 200g firm tofu (cubed and grilled/pan-fried), large portion of mixed stir-fried vegetables (e.g., broccoli, bell peppers, carrots, mushrooms, snow peas), seasoned with soy sauce/tamari and 1 tsp sesame oil. Served with 1.5 cups (cooked) brown rice."
#   },
#   "workout_plan": {
#     "frequency_per_week": 4,
#     "warm_up": "Begin each session with 5-10 minutes of light cardiovascular activity (e.g., jogging in place, jumping jacks, cycling) followed by 5 minutes of dynamic stretches (e.g., arm circles, leg swings, torso twists, cat-cow) to prepare your body for movement.",
#     "main_workout": "Engage in 4 main workout sessions per week, ideally structured as two strength training days and two cardiovascular/conditioning days.\n\n**Strength Training Days (2x/week):** Focus on full-body compound movements to build muscle and boost metabolism. Perform 3-4 sets of 8-12 repetitions for exercises like Squats, Deadlifts (or Romanian Deadlifts), Push-ups, Overhead Press, Bent-over Rows, and Lunges. Use a challenging weight where the last few reps are difficult to complete with good form. Rest 60-90 seconds between sets. Incorporate core work such as Planks (3 sets, 30-60 seconds hold) or Russian Twists (3 sets, 15-20 reps per side).\n\n**Cardiovascular/Conditioning Days (2x/week):**\n*   **High-Intensity Interval Training (HIIT):** 20-30 minutes. Examples: Sprint intervals (e.g., 30 seconds max effort run/cycle, 60 seconds walk/light cycle, repeat 10-15 times), Burpees, Mountain Climbers, or Jump Rope circuits. Aim for bursts of maximum effort followed by short recovery periods.\n*   **Moderate-Intensity Steady-State Cardio:** 30-45 minutes. Examples: Brisk walking, jogging, cycling, swimming, or elliptical. Maintain a pace where you can talk but feel slightly breathless. \n\nEnsure at least one rest day between strength training sessions and allow for 1-2 full rest days per week.",
#     "cool_down": "Conclude each workout with 5-10 minutes of static stretching, holding each stretch for 20-30 seconds. Focus on major muscle groups worked during your session, such as hamstrings, quadriceps, glutes, chest, back, and shoulders. This helps improve flexibility and aids in recovery."
#   },
#   "weekly_strategy": {
#     "weekly_schedule": {
#       "Monday": "Kickstart your week with purpose!\n**Workout:** Strength Training Day (Warm-up, Full-Body Compound Movements: Squats, Deadlifts/Romanian Deadlifts, Push-ups, Overhead Press, Bent-over Rows, Lunges, plus Core Work: Planks/Russian Twists, then Cool-down).\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"Embrace the challenge of a new week! Every rep and every healthy meal builds a stronger you.\"",
#       "Tuesday": "Keep the momentum rolling!\n**Workout:** Cardiovascular/Conditioning Day (Warm-up, choose either HIIT for 20-30 mins OR Moderate-Intensity Steady-State Cardio for 30-45 mins, then Cool-down).\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"Feel the burn and the boost! Your heart and lungs are getting stronger with every stride or sprint.\"",
#       "Wednesday": "A crucial day for recovery and rejuvenation.\n**Workout:** Rest Day. Focus on light activity like stretching or a gentle walk if desired, but prioritize recovery.\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"Rest is not laziness; it's smart training. Allow your body to repair and grow stronger. Hydrate consistently today!\"",
#       "Thursday": "Return to strength with renewed energy!\n**Workout:** Strength Training Day (Warm-up, Full-Body Compound Movements: Squats, Deadlifts/Romanian Deadlifts, Push-ups, Overhead Press, Bent-over Rows, Lunges, plus Core Work: Planks/Russian Twists, then Cool-down).\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"Push past yesterday's limits! Each challenging lift builds not just muscle, but also mental fortitude.\"",
#       "Friday": "Finish your workout week strong!\n**Workout:** Cardiovascular/Conditioning Day (Warm-up, choose either HIIT for 20-30 mins OR Moderate-Intensity Steady-State Cardio for 30-45 mins, then Cool-down).\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"You've been consistent and dedicated! Celebrate your hard work and enjoy the feeling of accomplishment as you head into the weekend.\"",
#       "Saturday": "A well-deserved rest day.\n**Workout:** Rest Day. Enjoy leisure activities, spend time outdoors, or simply relax.\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"Use today to reflect on your week's successes. Recharge your mind and body, and prepare for a fresh start!\"",
#       "Sunday": "Ease into the new week with another day of recovery.\n**Workout:** Rest Day. Perhaps a gentle walk or some mindful stretching. It's also a great day for meal prepping if that helps your routine!\n**Meals:**\n*   **Breakfast:** High-Protein Greek Yogurt Bowl\n*   **Mid-morning Snack:** 1 large apple\n*   **Lunch:** Hearty Lentil & Chickpea Salad with Brown Rice\n*   **Mid-afternoon Snack:** Protein shake (1.5 scoops plant-based protein) & 1/4 cup almonds\n*   **Dinner:** Tofu & Vegetable Stir-fry with Brown Rice\n*   **Motivation:** \"Nourish your body and mind today. This is your time to relax, reset, and set intentions for a powerful week ahead!\""
#     },
#     "motivation_tips": [
#       "Consistency is your superpower: Small, consistent efforts compound over time into incredible results. Keep showing up for yourself!",
#       "Listen to your body: Understand the difference between a challenge and pain. Rest and recovery are just as crucial as your workouts.",
#       "Celebrate every milestone: Whether it's finishing a tough workout, choosing a healthy snack, or hitting a new personal best, acknowledge your progress.",
#       "Stay hydrated: Water is essential for energy, muscle function, and overall well-being. Make it your constant companion.",
#       "Mindful eating: Savor your meals. Pay attention to how the food makes you feel, fueling your body for performance and recovery.",
#       "Find your 'why': On challenging days, reconnect with the core reasons you started this journey. Let that inner drive be your fuel."
#     ]
#   }
# }
